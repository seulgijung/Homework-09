# %%
# !pip install playwright nest_asyncio --quiet
# !playwright install firefox

import asyncio
import nest_asyncio
nest_asyncio.apply()

from playwright.async_api import async_playwright
from IPython.display import Image, display
import tempfile

async def load_page():
    print("Launching Firefox browser (headless=False)...")
    async with async_playwright() as p:
        browser = await p.firefox.launch(headless=False)
        page = await browser.new_page()

        print("Navigating to page...")
        await page.goto("https://www.applesfromny.com/varieties/", wait_until="networkidle")

        print("Page loaded! Taking screenshot...")

        tmp = tempfile.NamedTemporaryFile(suffix=".png", delete=False)
        await page.screenshot(path=tmp.name)

        display(Image(filename=tmp.name))

        html = await page.content()

        print("HTML captured! Closing browser...")
        await browser.close()

        return html

# ✅ This works inside Jupyter:
html_text = await load_page()

print("\nHTML successfully saved to variable: html_text")
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Launching Firefox browser (headless=False)...
# Navigating to page...
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[6], line 36
#      33         return html
#      35 # ✅ This works inside Jupyter:
# ---> 36 html_text = await load_page()
#      38 print("\nHTML successfully saved to variable: html_text")
#
# Cell In[6], line 19, in load_page()
#      16 page = await browser.new_page()
#      18 print("Navigating to page...")
# ---> 19 await page.goto("https://www.applesfromny.com/varieties/", wait_until="networkidle")
#      21 print("Page loaded! Taking screenshot...")
#      23 tmp = tempfile.NamedTemporaryFile(suffix=".png", delete=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/async_api/_generated.py:8992, in Page.goto(self, url, timeout, wait_until, referer)
#    8931 async def goto(
#    8932     self,
#    8933     url: str,
#    (...)   8939     referer: typing.Optional[str] = None,
#    8940 ) -> typing.Optional["Response"]:
#    8941     """Page.goto
#    8942
#    8943     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)   8988     Union[Response, None]
#    8989     """
#    8991     return mapping.from_impl_nullable(
# -> 8992         await self._impl_obj.goto(
#    8993             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8994         )
#    8995     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_page.py:555, in Page.goto(self, url, timeout, waitUntil, referer)
#     548 async def goto(
#     549     self,
#     550     url: str,
#    (...)    553     referer: str = None,
#     554 ) -> Optional[Response]:
# --> 555     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)    148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)     67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_connection.py:559, in Connection.wrap_api_call(self, cb, is_internal, title)
#     557     return await cb()
#     558 except Exception as error:
# --> 559     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     560 finally:
#     561     self._api_zone.set(None)
#
# TimeoutError: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.applesfromny.com/varieties/", waiting until "networkidle"

# %%
# !pip install playwright nest_asyncio --quiet
# !playwright install firefox

import asyncio
import nest_asyncio
nest_asyncio.apply()

from playwright.async_api import async_playwright

async def load_page():
    print("Launching Firefox browser (headless=False)...")
    async with async_playwright() as p:
        browser = await p.firefox.launch(headless=False)
        page = await browser.new_page()

        print("Navigating to page...")
        await page.goto("https://www.applesfromny.com/varieties/", wait_until="networkidle")

        print("Page loaded. Capturing HTML...")
        html = await page.content()

        print("Closing browser...")
        await browser.close()

        return html

html_text = await load_page()

print("HTML saved to variable: html_text")
print("Length of HTML:", len(html_text))
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Launching Firefox browser (headless=False)...
# Navigating to page...
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[7], line 27
#      23         await browser.close()
#      25         return html
# ---> 27 html_text = await load_page()
#      29 print("HTML saved to variable: html_text")
#      30 print("Length of HTML:", len(html_text))
#
# Cell In[7], line 17, in load_page()
#      14 page = await browser.new_page()
#      16 print("Navigating to page...")
# ---> 17 await page.goto("https://www.applesfromny.com/varieties/", wait_until="networkidle")
#      19 print("Page loaded. Capturing HTML...")
#      20 html = await page.content()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/async_api/_generated.py:8992, in Page.goto(self, url, timeout, wait_until, referer)
#    8931 async def goto(
#    8932     self,
#    8933     url: str,
#    (...)   8939     referer: typing.Optional[str] = None,
#    8940 ) -> typing.Optional["Response"]:
#    8941     """Page.goto
#    8942
#    8943     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)   8988     Union[Response, None]
#    8989     """
#    8991     return mapping.from_impl_nullable(
# -> 8992         await self._impl_obj.goto(
#    8993             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8994         )
#    8995     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_page.py:555, in Page.goto(self, url, timeout, waitUntil, referer)
#     548 async def goto(
#     549     self,
#     550     url: str,
#    (...)    553     referer: str = None,
#     554 ) -> Optional[Response]:
# --> 555     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)    148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)     67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_connection.py:559, in Connection.wrap_api_call(self, cb, is_internal, title)
#     557     return await cb()
#     558 except Exception as error:
# --> 559     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     560 finally:
#     561     self._api_zone.set(None)
#
# TimeoutError: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.applesfromny.com/varieties/", waiting until "networkidle"

# %%
if "html_text" in globals():
    print("✅ html_text exists!")
    
    mid = len(html_text) // 2
    preview = html_text[mid-500 : mid+500]
    
    print("\n--- MIDDLE 1000 CHARACTERS OF PAGE ---\n")
    print(preview)
else:
    print("❌ html_text does NOT exist. The page was not captured correctly.")
# Out:
# ❌ html_text does NOT exist. The page was not captured correctly.

# %%
from playwright.async_api import async_playwright
import nest_asyncio
nest_asyncio.apply()

print("Starting Playwright...")

async def load_page_and_store():
    global html_text  # ✅ force it to stay in memory

    async with async_playwright() as p:
        print("Launching Firefox...")
        browser = await p.firefox.launch(headless=False)
        page = await browser.new_page()

        print("Going to page...")
        await page.goto("https://www.applesfromny.com/varieties/", wait_until="networkidle")

        print("Capturing HTML now...")
        html_text = await page.content()

        print("HTML captured! Length:", len(html_text))

        print("Closing browser...")
        await browser.close()

await load_page_and_store()

print("✅ DONE — html_text is now saved globally")
# Out:
# Starting Playwright...
# Launching Firefox...
# Going to page...
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[9], line 26
#      23         print("Closing browser...")
#      24         await browser.close()
# ---> 26 await load_page_and_store()
#      28 print("✅ DONE — html_text is now saved globally")
#
# Cell In[9], line 16, in load_page_and_store()
#      13 page = await browser.new_page()
#      15 print("Going to page...")
# ---> 16 await page.goto("https://www.applesfromny.com/varieties/", wait_until="networkidle")
#      18 print("Capturing HTML now...")
#      19 html_text = await page.content()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/async_api/_generated.py:8992, in Page.goto(self, url, timeout, wait_until, referer)
#    8931 async def goto(
#    8932     self,
#    8933     url: str,
#    (...)   8939     referer: typing.Optional[str] = None,
#    8940 ) -> typing.Optional["Response"]:
#    8941     """Page.goto
#    8942
#    8943     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)   8988     Union[Response, None]
#    8989     """
#    8991     return mapping.from_impl_nullable(
# -> 8992         await self._impl_obj.goto(
#    8993             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8994         )
#    8995     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_page.py:555, in Page.goto(self, url, timeout, waitUntil, referer)
#     548 async def goto(
#     549     self,
#     550     url: str,
#    (...)    553     referer: str = None,
#     554 ) -> Optional[Response]:
# --> 555     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)    148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)     67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/playwright/_impl/_connection.py:559, in Connection.wrap_api_call(self, cb, is_internal, title)
#     557     return await cb()
#     558 except Exception as error:
# --> 559     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     560 finally:
#     561     self._api_zone.set(None)
#
# TimeoutError: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.applesfromny.com/varieties/", waiting until "networkidle"

# %%
from playwright.async_api import async_playwright
import nest_asyncio
nest_asyncio.apply()

async def load_page_and_store():
    global html_text

    async with async_playwright() as p:
        print("Launching Firefox...")
        browser = await p.firefox.launch(headless=False)
        page = await browser.new_page()

        print("Going to page (domcontentloaded)...")
        await page.goto("https://www.applesfromny.com/varieties/", wait_until="domcontentloaded")

        print("Waiting 2 seconds for page to settle...")
        await page.wait_for_timeout(2000)

        print("Capturing HTML...")
        html_text = await page.content()
        print("HTML captured! Length:", len(html_text))

        print("Closing browser...")
        await browser.close()

await load_page_and_store()

print("✅ DONE — html_text is now stored globally")
# Out:
# Launching Firefox...
# Going to page (domcontentloaded)...
# Waiting 2 seconds for page to settle...
# Capturing HTML...
# HTML captured! Length: 755589
# Closing browser...
# ✅ DONE — html_text is now stored globally

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_text, "html.parser")

# Find just the first apple card
first_apple = soup.find("div", class_="apple-variety")

# Extract fields safely
name = first_apple.find("h2").get_text(strip=True)

description = first_apple.find("p").get_text(strip=True)

detail_url = first_apple.find("a")["href"]

image_url = first_apple.find("img")["src"]

# Extract the sweetness scale number from class like: scale-7
scale_div = first_apple.find("div", class_="scale-icon")
scale_class = scale_div["class"]
sweetness = [c.replace("scale-", "") for c in scale_class if c.startswith("scale-")][0]

print("✅ TEST SCRAPE RESULT:\n")
print("Name:", name)
print("Description:", description)
print("Detail URL:", detail_url)
print("Image URL:", image_url)
print("Sweet–Tart Scale:", sweetness)
# Out:
# ✅ TEST SCRAPE RESULT:
#
# Name: 20 Ounce
# Description: This heirloom variety is famous not only for its size, but excellent cooking qualities as well.
# Detail URL: https://www.applesfromny.com/varieties/20-ounce/
# Image URL: https://www.applesfromny.com/wp-content/uploads/2020/05/20Ounce_NYAS-Apples2.png
# Sweet–Tart Scale: icon
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:3098: RuntimeWarning: coroutine 'load_page' was never awaited
#   params = OrderedDict((param.name, param) for param in parameters)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
# Re-extract just the sweetness correctly

scale_div = first_apple.find("div", class_="scale-icon")

# Get the class that looks like "scale-7"
scale_class = scale_div["class"]
sweetness = [c for c in scale_class if c.startswith("scale-")][0]
sweetness_number = sweetness.replace("scale-", "")

print("✅ Corrected Sweet–Tart Scale:", sweetness_number)
# Out:
# ✅ Corrected Sweet–Tart Scale: icon

# %%
# ✅ FINAL, robust sweetness extraction

scale_container = first_apple.find("div", class_="sweet-tart-scale")

all_divs = scale_container.find_all("div")

sweetness_number = None

for d in all_divs:
    classes = d.get("class", [])
    for c in classes:
        if c.startswith("scale-") and c != "scale-icon":
            sweetness_number = c.replace("scale-", "")

print("✅ Correct Sweet–Tart Scale:", sweetness_number)
# Out:
# ✅ Correct Sweet–Tart Scale: 7

# %%
from bs4 import BeautifulSoup
import pandas as pd

soup = BeautifulSoup(html_text, "html.parser")

apple_cards = soup.find_all("div", class_="apple-variety")

print("Total apples found:", len(apple_cards))

rows = []

for apple in apple_cards:
    name = apple.find("h2").get_text(strip=True)
    description = apple.find("p").get_text(strip=True)
    detail_url = apple.find("a")["href"]
    image_url = apple.find("img")["src"]

    # Sweet–Tart scale (robust version)
    scale_container = apple.find("div", class_="sweet-tart-scale")
    all_divs = scale_container.find_all("div")

    sweetness_number = None
    for d in all_divs:
        classes = d.get("class", [])
        for c in classes:
            if c.startswith("scale-") and c != "scale-icon":
                sweetness_number = c.replace("scale-", "")

    rows.append({
        "name": name,
        "description": description,
        "detail_url": detail_url,
        "image_url": image_url,
        "sweet_tart_scale": sweetness_number
    })

df = pd.DataFrame(rows)

print("\n✅ Preview of first 5 rows:\n")
df.head()
# Out:
# Total apples found: 30
#
# ✅ Preview of first 5 rows:
#            name                                        description  \
# 0      20 Ounce  This heirloom variety is famous not only for i...
# 1      Acey Mac                             Sweet, tart and juicy.
# 2  Autumn Crisp  Cross between a Golden Delicious and a Monroe ...
# 3      Braeburn                            Sweet, tangy and juicy.
# 4         Cameo  A bright, red-striped apple with a creamy oran...
#
#                                           detail_url  \
# 0   https://www.applesfromny.com/varieties/20-ounce/
# 1   https://www.applesfromny.com/varieties/acey-mac/
# 2  https://www.applesfromny.com/varieties/autumn-...
# 3   https://www.applesfromny.com/varieties/braeburn/
# 4      https://www.applesfromny.com/varieties/cameo/
#
#                                            image_url sweet_tart_scale
# 0  https://www.applesfromny.com/wp-content/upload...                7
# 1  https://www.applesfromny.com/wp-content/upload...                6
# 2  https://www.applesfromny.com/wp-content/upload...                4
# 3  https://www.applesfromny.com/wp-content/upload...                6
# 4  https://www.applesfromny.com/wp-content/upload...                2

# %%
output_path = "apple_varieties.csv"

df.to_csv(output_path, index=False)

print(f"✅ CSV file saved as: {output_path}")

# Show file size as a quick sanity check
import os
print("File size (bytes):", os.path.getsize(output_path))
# Out:
# ✅ CSV file saved as: apple_varieties.csv
# File size (bytes): 10194
